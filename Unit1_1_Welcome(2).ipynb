# %% [markdown]
# # Welcome to Computer Science at REALM.

# %% [markdown]
# #### Spring 2015 // Ms. Jenkins

# %% [markdown]
# # You will learn how to program in Python in this class.

# %%
Image(filename=('Desktop/ball-python.jpg'))

# %% [markdown]
# # This class will be

# %% [markdown]
# ## frustrating, difficult, and unlike any class you've ever had.

# %% [markdown]
# # If I'm doing my job,

# %% [markdown]
# ## you will develop confidence and you will learn how to teach yourself.

# %% [markdown]
# # This class will not be a place where you have free time.

# %% [markdown]
# # This is a safe space for all people

# %% [markdown]
# #### regardless of gender, race, sexual orientation and ability.
